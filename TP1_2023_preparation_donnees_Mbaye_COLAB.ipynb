# %% [markdown]
# BDLE 2023
#
# date du document  :  18/09/2023

# %% [markdown]
# # TP1 2023 Préparation de données  (Mbaye)
#
#
# Préparation de données

# %% [markdown]
# ## Préparation du TP

# %% [markdown]
# Vérifier que des ressources de calcul sont allouées à votre notebook  (cf RAM  de disque indiqués en haut à droite) . Sinon cliquer sur le bouton connecter pour obtenir des ressources.

# %% [markdown]
# Pour accéder directement aux fichiers stockées sur votre google drive. Renseigner le code d'authentification lorsqu'il est demandé
#
# Ajuster le nom de votre dossier : MyDrive/ens/bdle/TP1

# %%
import os
from google.colab import drive
drive.mount("/content/drive")

drive_dir = "/content/drive/MyDrive/ens/bdle/TP1"
os.makedirs(drive_dir, exist_ok=True)
os.listdir(drive_dir)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# []

# %% [markdown]
# Installer pyspark et findspark (durée 1'):

# %%
# !pip install -q pyspark
# !pip install -q findspark
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.9/316.9 MB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for pyspark (setup.py) ... done

# %% [markdown]
# Démarrer la session spark

# %%
import os
import glob

pyspark_dir = glob.glob('/usr/local/lib/python*/dist-packages/pyspark')[0]
print("pyspark directory is", pyspark_dir)
os.environ["SPARK_HOME"] = pyspark_dir
os.environ["JAVA_HOME"] = "/usr"
# Out:
# pyspark directory is /usr/local/lib/python3.10/dist-packages/pyspark

# %%
# Principaux import
import findspark
from pyspark.sql import SparkSession
from pyspark import SparkConf

# pour les dataframe et udf
from pyspark.sql import *
from pyspark.sql.functions import *
from pyspark.sql.types import *
from datetime import *

# pour le chronomètre
import time

# initialise les variables d'environnement pour spark
findspark.init()

# Démarrage session spark
# --------------------------
def demarrer_spark():
  local = "local[*]"
  appName = "TP"
  configLocale = SparkConf().setAppName(appName).setMaster(local).\
  set("spark.executor.memory", "6G").\
  set("spark.driver.memory","6G").\
  set("spark.sql.catalogImplementation","in-memory")

  spark = SparkSession.builder.config(conf = configLocale).getOrCreate()
  sc = spark.sparkContext
  sc.setLogLevel("ERROR")

  spark.conf.set("spark.sql.autoBroadcastJoinThreshold","-1")

  # On ajuste l'environnement d'exécution des requêtes à la taille du cluster (4 coeurs)
  spark.conf.set("spark.sql.shuffle.partitions","4")
  print("session démarrée, son id est ", sc.applicationId)
  return spark
spark = demarrer_spark()
# Out:
# session démarrée, son id est  local-1696098007619

# %%
# on utilise 8 partitions au lieu de 200 par défaut
spark.conf.set("spark.sql.shuffle.partitions", "8")
print("Nombre de partitions utilisées : ", spark.conf.get("spark.sql.shuffle.partitions"))
# Out:
# Nombre de partitions utilisées :  8

# %%
# Optionnel :
# pour l'accès à spark UI : voir https://www.analyticsvidhya.com/blog/2020/11/a-must-read-guide-on-how-to-work-with-pyspark-on-google-colab-for-data-scientists/
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
# get_ipython().system_raw('./ngrok http 4050 &')
# !curl -s http://localhost:4040/api/tunnels

# %% [markdown]
# Redéfinir la fonction **display** pour afficher le resutltat des requêtes dans un tableau

# %%
import pandas as pd
from google.colab import data_table

# alternatives to Databricks display function.

def display(df, n=100):
  return data_table.DataTable(df.limit(n).toPandas(), include_index=False, num_rows_per_page=10)

def display2(df, n=20):
  pd.set_option('max_columns', None)
  pd.set_option('max_colwidth', None)
  return df.limit(n).toPandas()

# %% [markdown]
# Définir le tag **%%sql** pour pouvoir écrire plus simplement des requêtes en SQL dans une cellule

# %%
from IPython.core.magic import (register_line_magic, register_cell_magic, register_line_cell_magic)

def removeComments(query):
  result = ""
  for line in query.split('\n'):
    if not(line.strip().startswith("--")):
      result += line + "\n"
  return result

@register_line_cell_magic
def sql(line, cell=None):
    "To run a sql query. Use:  %%sql"
    val = cell if cell is not None else line
    tabRequetes = removeComments(val).split(";")
    derniere = None
    est_requete = False
    for r in tabRequetes:
        r = r.strip()
        if len(r) > 2:
          derniere = spark.sql(r)
          est_requete = ( r.lower().startswith('select') or r.lower().startswith('with'))
    if(est_requete):
      return display(derniere)
    else:
      return print('ok')

# %%
# facultatif (à ne pas utiliser)
# %load_ext google.colab.data_table
# %unload_ext google.colab.data_table

# %% [markdown]
# ## Accès aux données

# %% [markdown]
# ### URL pour l'accès aux datasets

# %%
# URL du dossier PUBLIC_DATASET contenant des fichiers de données pour les TP
# ---------------------------------------------------------------------------
# en cas de problème avec le téléchargement des datasets, aller directement sur l'URL ci-dessous
PUBLIC_DATASET_URL = "https://nuage.lip6.fr/s/H3bpyRGgnCq2NR4"
PUBLIC_DATASET=PUBLIC_DATASET_URL + "/download?path="

print("URL du dossier contenant les datasets ", PUBLIC_DATASET_URL)
# Out:
# URL du dossier contenant les datasets  https://nuage.lip6.fr/s/H3bpyRGgnCq2NR4

# %% [markdown]
# ### Données de mobilité

# %% [markdown]
# Données issues du dataset YFCC

# %%
local_dir = "/local/data"
os.makedirs(local_dir, exist_ok=True)
os.listdir(local_dir)
# Out:
# []

# %%
from urllib import request

# download dataset if not already donwloaded
def download_file(web_dir, local_dir, file):
  local_file = local_dir + "/" + file
  web_file = web_dir + "/" + file
  if(os.path.isfile(local_file)):
    print(file, "is already stored")
  else:
    print("downloading from URL: ", web_file , "save in : " + local_file)
    request.urlretrieve(web_file , local_file)

# user visits
web_dir = PUBLIC_DATASET + "YFCC_POI_dataset_K_H_LIM/dataset_IJCAI_2015/data-ijcai15/userVisits-ijcai15"
download_file(web_dir, local_dir, "userVisits-Toro.csv")

# poi
web_dir = PUBLIC_DATASET + "YFCC_POI_dataset_K_H_LIM/dataset_IJCAI_2015/data-ijcai15/poiList-ijcai15"
download_file(web_dir, local_dir, "POI-Toro.csv")



os.listdir(local_dir)
# Out:
# downloading from URL:  https://nuage.lip6.fr/s/H3bpyRGgnCq2NR4/download?path=YFCC_POI_dataset_K_H_LIM/dataset_IJCAI_2015/data-ijcai15/userVisits-ijcai15/userVisits-Toro.csv save in : /local/data/userVisits-Toro.csv
# downloading from URL:  https://nuage.lip6.fr/s/H3bpyRGgnCq2NR4/download?path=YFCC_POI_dataset_K_H_LIM/dataset_IJCAI_2015/data-ijcai15/poiList-ijcai15/POI-Toro.csv save in : /local/data/POI-Toro.csv
# ['userVisits-Toro.csv', 'POI-Toro.csv']

# %% [markdown]
# ### Les visites

# %% [markdown]
# Lire les 2 premières lignes du  fichier csv en python.
# Est ce que le fichier a une ligne d'entête ?
# Quel caractère délimite deux valeurs consécutives dans une ligne de données ?

# %%
f = open(local_dir + "/" + "userVisits-Toro.csv", "r")
print(f.readline()); print(f.readline())
# Out:
# "photoID";"userID";"dateTaken";"poiID";"poiTheme";"poiFreq";"seqID"
#
# 7941504100;"10007579@N00";1346844688;30;"Structure";1538;1

# %% [markdown]
# Lire le fichier des visites *sans* préciser le type des attributs.
# Par défaut, tous les attributs sont considérés comme étant de type string.

# %%
user_visits = spark.read.option("header", "True").option("delimiter", ";").format("csv").load(local_dir + "/" + "userVisits-Toro.csv")
user_visits.show(3)
user_visits.printSchema()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d8d2bf50be0a> in <cell line: 1>()
# ----> 1 user_visits = spark.read.option("header", "True").option("delimiter", ";").format("csv").load(local_dir + "/" + "userVisits-Toro.csv")
#       2 user_visits.show(3)
#       3 user_visits.printSchema()
#
# NameError: name 'spark' is not defined

# %% [markdown]
# Lire le fichier en précisant le schéma : nom et type des attributs

# %%
schema = "photoID long, userID String, date Long, poiID int, poiTheme String, poiFreq int, seqID int"

user_visits = spark.read.option("header", "True").option("delimiter", ";").csv(local_dir + "/" + "userVisits-Toro.csv", schema = schema)
user_visits.persist()
user_visits.createOrReplaceTempView("user_visits")
user_visits.show(10)
user_visits.printSchema()
# Out:
# +----------+------------+----------+-----+---------+-------+-----+
# |   photoID|      userID|      date|poiID| poiTheme|poiFreq|seqID|
# +----------+------------+----------+-----+---------+-------+-----+
# |7941504100|10007579@N00|1346844688|   30|Structure|   1538|    1|
# |4886005532|10012675@N05|1142731848|    6| Cultural|    986|    2|
# |4886006468|10012675@N05|1142732248|    6| Cultural|    986|    2|
# |4885404441|10012675@N05|1142732373|    6| Cultural|    986|    2|
# |4886008334|10012675@N05|1142732445|    6| Cultural|    986|    2|
# |4886009150|10012675@N05|1142916492|    6| Cultural|    986|    3|
# |7054481539|10012675@N05|1319327174|   13| Cultural|    964|    4|
# |6908387594|10012675@N05|1319328255|   13| Cultural|    964|    4|
# |6908381912|10012675@N05|1319331463|   13| Cultural|    964|    4|
# |6908398496|10012675@N05|1319331886|   13| Cultural|    964|    4|
# +----------+------------+----------+-----+---------+-------+-----+
# only showing top 10 rows
#
# root
#  |-- photoID: long (nullable = true)
#  |-- userID: string (nullable = true)
#  |-- date: long (nullable = true)
#  |-- poiID: integer (nullable = true)
#  |-- poiTheme: string (nullable = true)
#  |-- poiFreq: integer (nullable = true)
#  |-- seqID: integer (nullable = true)

# %% [markdown]
# Vérifier qu'il n'y a pas de date nulle

# %%
# %%sql
# select count(1) as nb_dates_nulles
# from user_visits
# where date is null
#
# -- autre solution avec "case"
# --select count(case when isnull(date) then date end) as nb_date_nulles
# --from user_visits
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>nb_dates_nulles</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Vérifier qu'il n'y a aucune séquence associée à plusieurs utilisateurs

# %%
# %%sql
# select seqID
# from user_visits
# group by seqID
# having count(distinct userID) > 1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>seqID</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### POI_sequence
#
# La table **POI_sequence**(seqID, poiID). Les POI visités durant une séquence.
# Pour simplifier on compte chaque POI une seule fois par séquence et on ne considère pas l'ordre de visite des POI.
#
# Rmq: il n'est pas nécessaire de préciser le userID pour identifier une séquence.

# %%
# %%sql
# create or replace temp view POI_sequence as
# select distinct seqID, poiID
# from user_visits;
#
# select * from POI_sequence
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>seqID</th>
#       <th>poiID</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>9</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>16</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>26</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>29</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>54</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>624</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>96</th>
#       <td>634</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>97</th>
#       <td>638</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>98</th>
#       <td>641</td>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td>658</td>
#       <td>22</td>
#     </tr>
#   </tbody>
# </table>
# <p>100 rows × 2 columns</p>
# </div>

# %% [markdown]
# ### Les lieux visités : POI
# Ils sont appelés *Point Of Interest*

# %%
poi_schema = "poiID long, poiName String, latitude double, longitude double, theme String"

poi = spark.read.option("header", "True").option("delimiter", ";").csv(local_dir + "/" + "POI-Toro.csv", schema = poi_schema)
poi.show(3)
poi.printSchema()
poi.createOrReplaceTempView("POI")
# Out:
# +-----+------------------+--------+---------+-----+
# |poiID|           poiName|latitude|longitude|theme|
# +-----+------------------+--------+---------+-----+
# |    1| Air_Canada_Centre|43.64333|-79.37917|Sport|
# |    2|         BMO_Field|43.63278|-79.41861|Sport|
# |    3|Maple_Leaf_Gardens|43.66222|-79.38028|Sport|
# +-----+------------------+--------+---------+-----+
# only showing top 3 rows
#
# root
#  |-- poiID: long (nullable = true)
#  |-- poiName: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- theme: string (nullable = true)

# %%
# %%sql
# cache table POI;
#
# SELECT *
# FROM POI
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poiID</th>
#       <th>poiName</th>
#       <th>latitude</th>
#       <th>longitude</th>
#       <th>theme</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Air_Canada_Centre</td>
#       <td>43.643330</td>
#       <td>-79.379170</td>
#       <td>Sport</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>BMO_Field</td>
#       <td>43.632780</td>
#       <td>-79.418610</td>
#       <td>Sport</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Maple_Leaf_Gardens</td>
#       <td>43.662220</td>
#       <td>-79.380280</td>
#       <td>Sport</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>Rogers_Centre</td>
#       <td>43.641390</td>
#       <td>-79.389170</td>
#       <td>Sport</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>Woodbine_Racetrack</td>
#       <td>43.712525</td>
#       <td>-79.602042</td>
#       <td>Sport</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>Art_Gallery_of_Ontario</td>
#       <td>43.653890</td>
#       <td>-79.392780</td>
#       <td>Cultural</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>Hockey_Hall_of_Fame</td>
#       <td>43.646976</td>
#       <td>-79.377253</td>
#       <td>Cultural</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>Ripley%27s_Aquarium_of_Canada</td>
#       <td>43.642481</td>
#       <td>-79.386050</td>
#       <td>Cultural</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>Ontario_Science_Centre</td>
#       <td>43.716670</td>
#       <td>-79.338330</td>
#       <td>Cultural</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>Riverdale_Farm</td>
#       <td>43.667111</td>
#       <td>-79.361294</td>
#       <td>Cultural</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>11</td>
#       <td>Royal_Ontario_Museum</td>
#       <td>43.667500</td>
#       <td>-79.394170</td>
#       <td>Cultural</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>12</td>
#       <td>Toronto_Zoo</td>
#       <td>43.820278</td>
#       <td>-79.182778</td>
#       <td>Cultural</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>13</td>
#       <td>Casa_Loma</td>
#       <td>43.678100</td>
#       <td>-79.409500</td>
#       <td>Cultural</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>14</td>
#       <td>Canadian_National_Exhibition</td>
#       <td>43.633330</td>
#       <td>-79.416670</td>
#       <td>Amusement</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>15</td>
#       <td>Centreville_Amusement_Park</td>
#       <td>43.620308</td>
#       <td>-79.373678</td>
#       <td>Amusement</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>16</td>
#       <td>CN_Tower</td>
#       <td>43.642600</td>
#       <td>-79.387100</td>
#       <td>Amusement</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>17</td>
#       <td>Exhibition_Place</td>
#       <td>43.632780</td>
#       <td>-79.416110</td>
#       <td>Amusement</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>18</td>
#       <td>Sunnyside_Amusement_Park</td>
#       <td>43.637923</td>
#       <td>-79.450786</td>
#       <td>Amusement</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>19</td>
#       <td>Toronto_Islands</td>
#       <td>43.620830</td>
#       <td>-79.378610</td>
#       <td>Beach</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>20</td>
#       <td>High_Park</td>
#       <td>43.646821</td>
#       <td>-79.462996</td>
#       <td>Beach</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>21</td>
#       <td>Yonge-Dundas_Square</td>
#       <td>43.656110</td>
#       <td>-79.380280</td>
#       <td>Beach</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>22</td>
#       <td>Nathan_Phillips_Square</td>
#       <td>43.652500</td>
#       <td>-79.383610</td>
#       <td>Beach</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>23</td>
#       <td>Toronto_Eaton_Centre</td>
#       <td>43.653982</td>
#       <td>-79.380319</td>
#       <td>Shopping</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>24</td>
#       <td>Harbourfront_Centre</td>
#       <td>43.638490</td>
#       <td>-79.382068</td>
#       <td>Shopping</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>25</td>
#       <td>Kensington_Market</td>
#       <td>43.654772</td>
#       <td>-79.400678</td>
#       <td>Shopping</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>26</td>
#       <td>Yorkdale_Shopping_Centre</td>
#       <td>43.725599</td>
#       <td>-79.452696</td>
#       <td>Shopping</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>27</td>
#       <td>Yorkville,_Toronto</td>
#       <td>43.670280</td>
#       <td>-79.391110</td>
#       <td>Shopping</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>28</td>
#       <td>Old_City_Hall_(Toronto)</td>
#       <td>43.652500</td>
#       <td>-79.381670</td>
#       <td>Structure</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>29</td>
#       <td>Ontario_Legislative_Building</td>
#       <td>43.662447</td>
#       <td>-79.391708</td>
#       <td>Structure</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>30</td>
#       <td>Union_Station_(Toronto)</td>
#       <td>43.645280</td>
#       <td>-79.380560</td>
#       <td>Structure</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# la liste des thèmes

# %%
# %%sql
# create or replace temp view themes as
# select distinct theme
# from POI
# order by theme;
#
# cache table themes;
#
# select *
# from themes
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>theme</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Amusement</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Beach</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Cultural</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Shopping</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Sport</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Structure</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Exercice 1

# %% [markdown]
# #### 1) Les 10 POI les plus photographiés
# indications: on peut compléter une requête SQL avec *LIMIT 10* pour borner la taille résultat (partiel) souhaité.

# %%
# %%sql
# create or replace temp view POI_nb_visites as
# select poiID, count(*) as nb_visites
# from user_visits
# group by poiID
# order by nb_visites DESC
#
# limit 10;
#
# select POI.poiName as nom
# from POI_nb_visites, POI
# where POI_nb_visites.poiID = POI.poiID;
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>nom</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Air_Canada_Centre</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Rogers_Centre</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Hockey_Hall_of_Fame</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Ripley%27s_Aquarium_of_Canada</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Royal_Ontario_Museum</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>CN_Tower</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Yonge-Dundas_Square</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Nathan_Phillips_Square</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Toronto_Eaton_Centre</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Kensington_Market</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### 2) Les visites avec date détaillée
# Définir la table Visite_date(userID, seqID, poiID, date, annee, mois, jour, heure) contenant les visites avec la date détaillée composée des attributs : année, mois, jour, heure.
# Indication : la date est initialement au format "unix". Voir la fonction de conversion de date from_unixtime et la fonction extract.

# %%
# %%sql
# create or replace temp view Visite_Date as
# select userID, seqID, poiID, date, FROM_UNIXTIME(date) as date2, extract(year from FROM_UNIXTIME(date)) as annee, extract(month from FROM_UNIXTIME(date)) mois, extract(day from FROM_UNIXTIME(date)) jour, extract(hour from FROM_UNIXTIME(date)) heure
# from user_visits
#
#
# ;
#
# select * from Visite_Date
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>userID</th>
#       <th>seqID</th>
#       <th>poiID</th>
#       <th>date</th>
#       <th>date2</th>
#       <th>annee</th>
#       <th>mois</th>
#       <th>jour</th>
#       <th>heure</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10007579@N00</td>
#       <td>1</td>
#       <td>30</td>
#       <td>1346844688</td>
#       <td>2012-09-05 11:31:28</td>
#       <td>2012</td>
#       <td>9</td>
#       <td>5</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>10012675@N05</td>
#       <td>2</td>
#       <td>6</td>
#       <td>1142731848</td>
#       <td>2006-03-19 01:30:48</td>
#       <td>2006</td>
#       <td>3</td>
#       <td>19</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>10012675@N05</td>
#       <td>2</td>
#       <td>6</td>
#       <td>1142732248</td>
#       <td>2006-03-19 01:37:28</td>
#       <td>2006</td>
#       <td>3</td>
#       <td>19</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>10012675@N05</td>
#       <td>2</td>
#       <td>6</td>
#       <td>1142732373</td>
#       <td>2006-03-19 01:39:33</td>
#       <td>2006</td>
#       <td>3</td>
#       <td>19</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>10012675@N05</td>
#       <td>2</td>
#       <td>6</td>
#       <td>1142732445</td>
#       <td>2006-03-19 01:40:45</td>
#       <td>2006</td>
#       <td>3</td>
#       <td>19</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>10014440@N06</td>
#       <td>10</td>
#       <td>25</td>
#       <td>1215593613</td>
#       <td>2008-07-09 08:53:33</td>
#       <td>2008</td>
#       <td>7</td>
#       <td>9</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>96</th>
#       <td>10014440@N06</td>
#       <td>10</td>
#       <td>25</td>
#       <td>1215593634</td>
#       <td>2008-07-09 08:53:54</td>
#       <td>2008</td>
#       <td>7</td>
#       <td>9</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>97</th>
#       <td>10014440@N06</td>
#       <td>10</td>
#       <td>25</td>
#       <td>1215593650</td>
#       <td>2008-07-09 08:54:10</td>
#       <td>2008</td>
#       <td>7</td>
#       <td>9</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>98</th>
#       <td>10014440@N06</td>
#       <td>10</td>
#       <td>25</td>
#       <td>1215593655</td>
#       <td>2008-07-09 08:54:15</td>
#       <td>2008</td>
#       <td>7</td>
#       <td>9</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td>10014440@N06</td>
#       <td>10</td>
#       <td>25</td>
#       <td>1215593674</td>
#       <td>2008-07-09 08:54:34</td>
#       <td>2008</td>
#       <td>7</td>
#       <td>9</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table>
# <p>100 rows × 9 columns</p>
# </div>

# %% [markdown]
# #### 3a) Le nombre de POI par utilisateur
# Le résultat (userID, nbPOI) est trié par nombre décroissant de POI.

# %%
# %%sql
# create or replace temp view Tab_nb_poid as
# select userID, count(*) as nbPOI
# from user_visits
# group by userID
#
# ;
#
# select * from Tab_nb_poid
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>userID</th>
#       <th>nbPOI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>11090433@N05</td>
#       <td>71</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>12641532@N00</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>12693966@N07</td>
#       <td>211</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>12874594@N08</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>13411198@N00</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>60261913@N00</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>96</th>
#       <td>60365624@N06</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>97</th>
#       <td>61117412@N07</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>98</th>
#       <td>62077150@N06</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td>62959750@N00</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>
# <p>100 rows × 2 columns</p>
# </div>

# %% [markdown]
# #### 3b) Le nombre de POI par séquence
# Définir la table Seq3plus(seqID, nbPoi) correspondant aux séquences qui contiennent au moins 3 POI distincts.
# Afficher le résultat trié par nombre de POI décroissant puis numéro de séquence croissant.

# %%
# %%sql
# create or replace temp view Seq3plus as
# select seqID, count(*) as nbPOI
# from user_visits
# group by seqID;
#
#
#
# select * from seq3plus
# order by nbPOI desc, seqID;
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>seqID</th>
#       <th>nbPOI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3935</td>
#       <td>643</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4635</td>
#       <td>412</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3933</td>
#       <td>373</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3011</td>
#       <td>320</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4632</td>
#       <td>316</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>1305</td>
#       <td>66</td>
#     </tr>
#     <tr>
#       <th>96</th>
#       <td>5294</td>
#       <td>66</td>
#     </tr>
#     <tr>
#       <th>97</th>
#       <td>558</td>
#       <td>65</td>
#     </tr>
#     <tr>
#       <th>98</th>
#       <td>2474</td>
#       <td>65</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td>2485</td>
#       <td>65</td>
#     </tr>
#   </tbody>
# </table>
# <p>100 rows × 2 columns</p>
# </div>

# %% [markdown]
# #### 4) Trajectoire

# %% [markdown]
# a) Définir une fonction qui prend en entrée une liste de couples (date, poi) et qui retourne une liste PoI triés par date croissante. Le resultat ne contient pas 2 PoI consécutifs identiques.

# %%
def trierPOI(l):
  result = sorted(l, key=lambda x : x[0])
  result = [x[1] for x in result]
  r = [result[0]]
  for i in range(1,len(result)):
    if result[i] != r[-1]:
      r.append(result[i])

  return r

spark.udf.register("trierPOI", trierPOI, ArrayType(IntegerType()))

# test local
print(trierPOI([(13,0),(10,2), (12,1), (14,2),(11,2)]))
# Out:
# [2, 1, 0, 2]

# %% [markdown]
# Définir la vue Trajectoire(userID, seqID, listPOI).
#
# listPOI est la liste des POI visités, pendant la séquence seqID, dans l'ordre chronologique
#
# Indications:
# pour la sequence 687 la listPOI est [7,16,4,8,4,16]

# %%
# %%sql
# create or replace temp view Trajectoire as
# select userId, seqID, trierPOI(collect_list((date,poiID))) as listePOI
# from user_visits
# group by userId,seqID;
#
#
# cache table Trajectoire;
#
# select * from Trajectoire
# where size(listePOI) =6
# order by seqID
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>userId</th>
#       <th>seqID</th>
#       <th>listePOI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>14617133@N05</td>
#       <td>384</td>
#       <td>[22, 28, 22, 28, 22, 28]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>20456447@N03</td>
#       <td>687</td>
#       <td>[7, 16, 4, 8, 4, 16]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>20741443@N00</td>
#       <td>729</td>
#       <td>[23, 21, 22, 7, 28, 23]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>27168489@N00</td>
#       <td>1358</td>
#       <td>[16, 8, 28, 22, 23, 21]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>29352917@N00</td>
#       <td>1524</td>
#       <td>[29, 30, 16, 29, 16, 29]</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>30624156@N00</td>
#       <td>1598</td>
#       <td>[28, 7, 30, 28, 22, 27]</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>32827327@N03</td>
#       <td>1786</td>
#       <td>[20, 6, 25, 11, 30, 24]</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>33547369@N00</td>
#       <td>1877</td>
#       <td>[23, 21, 23, 22, 23, 22]</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>34128007@N04</td>
#       <td>1912</td>
#       <td>[8, 16, 4, 1, 29, 16]</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>34314322@N00</td>
#       <td>1993</td>
#       <td>[30, 22, 28, 29, 30, 16]</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>35034347485@N01</td>
#       <td>2069</td>
#       <td>[6, 21, 23, 28, 22, 28]</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>35237095252@N01</td>
#       <td>2158</td>
#       <td>[30, 7, 30, 16, 4, 16]</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>44925192@N00</td>
#       <td>2916</td>
#       <td>[21, 7, 30, 16, 4, 16]</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>49503002894@N01</td>
#       <td>3401</td>
#       <td>[22, 8, 22, 8, 22, 3]</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>51035610516@N01</td>
#       <td>3501</td>
#       <td>[21, 30, 8, 16, 4, 16]</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>51035681908@N01</td>
#       <td>3504</td>
#       <td>[21, 22, 4, 16, 25, 11]</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>84987970@N00</td>
#       <td>5180</td>
#       <td>[22, 28, 22, 23, 21, 22]</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>84987970@N00</td>
#       <td>5250</td>
#       <td>[30, 23, 21, 22, 6, 16]</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>84987970@N00</td>
#       <td>5276</td>
#       <td>[6, 4, 30, 7, 28, 21]</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>86292040@N00</td>
#       <td>5377</td>
#       <td>[30, 1, 8, 16, 8, 23]</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### 5) Transitions
# 5a) Définir la table Transitions(poi1, poi2, nbTrans) avec nbTrans étant le nombre de déplacements directs de poi1 à poi2.
# Indication: deux POI apparaissant successivement (poi1 suivi de poi2) dans une séquence forment un déplacement direct entre poi1 et poi2.
# Une séquence contenant un seul POI ne correspond à aucun déplacement.

# %%
def transition(listePOI):
  result = []
  for ipoi1,poi2 in enumerate(listePOI[1:]):
    poi1 = listePOI[ipoi1]
    result.append((poi1,poi2))
  return result

spark.udf.register("transition", transition, ArrayType(StructType([StructField("poi1", IntegerType()), StructField("poi2", IntegerType())] )))
# Out:
# <function __main__.transition(listePOI)>

# %%
# %%sql
# create or replace temp view Transition1 as
#   select poi1_poi2.poi1, poi1_poi2.poi2, count(*) as nbTrans
#   from (select explode(transition(listePOI)) as poi1_poi2
#         from Trajectoire
#         where size(listePOI) >1)
#   group by poi1_poi2.poi1, poi1_poi2.poi2;
#
#
# cache table Transition1;
# select *
# from Transition1 t
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poi1</th>
#       <th>poi2</th>
#       <th>nbTrans</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>23</td>
#       <td>24</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>11</td>
#       <td>27</td>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>28</td>
#       <td>23</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>25</td>
#       <td>6</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>22</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>30</td>
#       <td>25</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>96</th>
#       <td>6</td>
#       <td>30</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>97</th>
#       <td>11</td>
#       <td>26</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>98</th>
#       <td>27</td>
#       <td>6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td>13</td>
#       <td>21</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>
# <p>100 rows × 3 columns</p>
# </div>

# %% [markdown]
# b) Definir la vue
# Transition_relative avec des valeurs de transition relatives au nombre total de transition partant d'un POI.
#
# Indication: créer une vue donnant le nombre total de transitions par poi.

# %%
# %%sql
# create or replace temp view Total_transition as
#   select poi1, sum(nbTrans) as total_trans
#   from Transition1
#   group by poi1;
#
# cache table Total_transition;
#
# select * from Total_transition;
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poi1</th>
#       <th>total_trans</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>14</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>13</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>23</td>
#       <td>211</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>16</td>
#       <td>166</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>9</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>61</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>17</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>10</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>11</td>
#       <td>68</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>3</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>7</td>
#       <td>153</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>26</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>1</td>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>27</td>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>25</td>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>19</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>30</td>
#       <td>159</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>29</td>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>15</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>20</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>28</td>
#       <td>166</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>22</td>
#       <td>211</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>4</td>
#       <td>61</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>2</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>24</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>21</td>
#       <td>166</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>8</td>
#       <td>93</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Verication pour un poid(10)

# %%
# %%sql
# select poi1, nbTrans
#   from Transition1
#   where poi1 = 10;
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poi1</th>
#       <th>nbTrans</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>10</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# %%sql
# create or replace temp view Transition_relative as
#   select t1.poi1, t1.poi2, t1.nbTrans/tt.total_trans as transition_rel
#   from Total_transition tt, Transition1 t1
#   where tt.poi1 = t1.poi1;
#
# cache table Transition_relative;
# select * from Transition_relative
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poi1</th>
#       <th>poi2</th>
#       <th>transition_rel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>7</td>
#       <td>0.111111</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>24</td>
#       <td>0.044444</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>4</td>
#       <td>0.022222</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>22</td>
#       <td>0.066667</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>30</td>
#       <td>0.311111</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>11</td>
#       <td>30</td>
#       <td>0.029412</td>
#     </tr>
#     <tr>
#       <th>96</th>
#       <td>13</td>
#       <td>16</td>
#       <td>0.200000</td>
#     </tr>
#     <tr>
#       <th>97</th>
#       <td>13</td>
#       <td>21</td>
#       <td>0.100000</td>
#     </tr>
#     <tr>
#       <th>98</th>
#       <td>13</td>
#       <td>4</td>
#       <td>0.050000</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td>13</td>
#       <td>27</td>
#       <td>0.050000</td>
#     </tr>
#   </tbody>
# </table>
# <p>100 rows × 3 columns</p>
# </div>

# %% [markdown]
# Verification

# %%
# %%sql
#   select poi1, sum(transition_rel)
#   from Transition_relative
#   group by poi1;
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poi1</th>
#       <th>sum(transition_rel)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>6</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>7</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>8</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>9</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>10</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>11</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>13</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>14</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>15</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>16</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>17</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>19</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>20</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>21</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>22</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>23</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>24</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>25</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>26</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>27</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>28</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>29</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>30</td>
#       <td>1.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### 6) DuréeVisitePOI
# La durée moyenne de visite d'un POI.
# Indication, pour une série d'événements consécutifs associés à un même POI dans une séquence, la durée de visite est la différence de date entre le 1er et le dernier événement.

# %%
def trierDate(l):
  result = sorted(l, key=lambda x : x[1])

  return result

spark.udf.register("trierDate", trierDate, ArrayType(StructType([StructField("poi", IntegerType()), StructField("date", IntegerType())] )))
# Out:
# <function __main__.trierDate(l)>

# %%
def dureeVisite(liste_couples):
  result = []
  taille = len(liste_couples)
  if len(liste_couples) < 2:
    return []

  i1 = 0
  while i1 < taille-2: # avant dernier element
    poi1,d1 = liste_couples[i1]
    i2 = i1
    while i2 < taille and liste_couples[i2][0] == poi1:
      i2 += 1
    i2 -= 1 # recul d'un pas

    if i1 != i2:
      d2 = liste_couples[i2][1]
      result.append((poi1,d2-d1))
    i1 = i2 + 1

  return result

spark.udf.register("dureeVisite", dureeVisite, ArrayType(StructType([StructField("poi", IntegerType()), StructField("duree", IntegerType())] )))

# test local
print(dureeVisite([(102,8), (102,11), (106,14) ,(101,15), (101,17), (102,20), (102,21), (102,24)]))
# Out:
# [(102, 3), (101, 2), (102, 4)]

# %%
# %%sql
# create or replace temp view DureeVisitePOI as
#   select userID, seqID, poi_duree.poi, poi_duree.duree
#   from  (select userID, seqID, explode(dureeVisite(trierDate(collect_list((poiID,date))))) as poi_duree
#           from user_visits
#           group by userID, seqID);
#
# cache table DureeVisitePOI;
#
# select *
# from DureeVisitePOI d
# order by userID, seqID
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>userID</th>
#       <th>seqID</th>
#       <th>poi</th>
#       <th>duree</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10012675@N05</td>
#       <td>2</td>
#       <td>6</td>
#       <td>597</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>10012675@N05</td>
#       <td>4</td>
#       <td>13</td>
#       <td>5674</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>10014440@N06</td>
#       <td>5</td>
#       <td>24</td>
#       <td>257</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>10014440@N06</td>
#       <td>6</td>
#       <td>23</td>
#       <td>1065</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>10014440@N06</td>
#       <td>7</td>
#       <td>23</td>
#       <td>573</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>12316147@N05</td>
#       <td>236</td>
#       <td>16</td>
#       <td>4577</td>
#     </tr>
#     <tr>
#       <th>96</th>
#       <td>12316147@N05</td>
#       <td>236</td>
#       <td>8</td>
#       <td>3251</td>
#     </tr>
#     <tr>
#       <th>97</th>
#       <td>12369809@N07</td>
#       <td>239</td>
#       <td>21</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>98</th>
#       <td>12369809@N07</td>
#       <td>240</td>
#       <td>11</td>
#       <td>6720</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td>12518297@N00</td>
#       <td>246</td>
#       <td>3</td>
#       <td>30</td>
#     </tr>
#   </tbody>
# </table>
# <p>100 rows × 4 columns</p>
# </div>

# %%
# %%sql
# create or replace temp view DureeMoyenneVisitePOI as
#   select userID, seqID, poi, mean(duree) as duree_moyenne
#   from DureeVisitePOI d
#   group by userID, seqID, poi
# ;
#
# cache table DureeMoyenneVisitePOI;
#
# select * from DureeMoyenneVisitePOI
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>userID</th>
#       <th>seqID</th>
#       <th>poi</th>
#       <th>duree_moyenne</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10014440@N06</td>
#       <td>6</td>
#       <td>23</td>
#       <td>1065.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>10285309@N08</td>
#       <td>36</td>
#       <td>1</td>
#       <td>11681.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>10502709@N05</td>
#       <td>73</td>
#       <td>25</td>
#       <td>15776.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>10627620@N06</td>
#       <td>99</td>
#       <td>23</td>
#       <td>129.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>10627620@N06</td>
#       <td>103</td>
#       <td>7</td>
#       <td>434.0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>32934461@N00</td>
#       <td>1792</td>
#       <td>8</td>
#       <td>5056.0</td>
#     </tr>
#     <tr>
#       <th>96</th>
#       <td>33228691@N00</td>
#       <td>1803</td>
#       <td>4</td>
#       <td>104.0</td>
#     </tr>
#     <tr>
#       <th>97</th>
#       <td>33547369@N00</td>
#       <td>1875</td>
#       <td>28</td>
#       <td>2834.0</td>
#     </tr>
#     <tr>
#       <th>98</th>
#       <td>33547369@N00</td>
#       <td>1876</td>
#       <td>22</td>
#       <td>6926.0</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td>33547369@N00</td>
#       <td>1877</td>
#       <td>23</td>
#       <td>2912.5</td>
#     </tr>
#   </tbody>
# </table>
# <p>100 rows × 4 columns</p>
# </div>

# %% [markdown]
# ### 7) Durée moyenne de déplacement entre deux POIs.
#
# Définir la vue **DureeDeplacement** (poi1, poi2, duree) calculant la duree moyenne de déplacement entre deux POI consécutifs dans une séquence.

# %% [markdown]
# ## Exercice 2

# %% [markdown]
# Charger les données de Geonames

# %%
import zipfile

#geonames
web_dir = PUBLIC_DATASET + "geonames_ALL"

download_file(web_dir, local_dir, "allCountries.zip")

#unzip
local_file = local_dir + "/" + "allCountries.txt"
if(os.path.isfile(local_file)):
    print(local_file, "is already stored")
else:
  with zipfile.ZipFile(local_dir + "/" + "allCountries.zip", 'r') as zip_ref:
    zip_ref.extractall(local_dir)

os.listdir(local_dir)
# Out:
# allCountries.zip is already stored
# /local/data/allCountries.txt is already stored
# ['userVisits-Toro.csv', 'allCountries.txt', 'allCountries.zip', 'POI-Toro.csv']

# %%
geonames =  spark.read.option("header", "False").option("delimiter", "\t").format("csv").load(local_dir + "/" + "allCountries.txt")
geonames.createOrReplaceTempView("geonames")
geonames.show(3)
# Out:
# +-------+--------------------+--------------------+--------------------+--------+-------+---+---+---+-----+----+----+----+----+----+----+----+--------------+----------+
# |    _c0|                 _c1|                 _c2|                 _c3|     _c4|    _c5|_c6|_c7|_c8|  _c9|_c10|_c11|_c12|_c13|_c14|_c15|_c16|          _c17|      _c18|
# +-------+--------------------+--------------------+--------------------+--------+-------+---+---+---+-----+----+----+----+----+----+----+----+--------------+----------+
# |2986043|  Pic de Font Blanca|  Pic de Font Blanca|Pic de Font Blanc...|42.64991|1.53335|  T| PK| AD| NULL|  00|NULL|NULL|NULL|   0|NULL|2860|Europe/Andorra|2014-11-05|
# |2994701|            Roc Mélé|            Roc Mele|Roc Mele,Roc Mele...|42.58765|1.74028|  T| MT| AD|AD,FR|  00|NULL|NULL|NULL|   0|NULL|2803|Europe/Andorra|2014-11-05|
# |3007683|Pic des Langounelles|Pic des Langounelles|Pic des Langounelles|42.61203|1.47364|  T| PK| AD|AD,FR|  00|NULL|NULL|NULL|   0|NULL|2685|Europe/Andorra|2014-11-05|
# +-------+--------------------+--------------------+--------------------+--------+-------+---+---+---+-----+----+----+----+----+----+----+----+--------------+----------+
# only showing top 3 rows

# %% [markdown]
# ### 1) Geonames
# Définir le schéma, limité au 9 premiers attributs donnant des informations sur l'identifiant d'un POI, ses noms, sa position GPS, le code du pays..., ), d'après le document [readme.txt](https://nuage.lip6.fr/s/kaBX3sF3YEzMZHK) dans le dossier [geonames_ALL](https://nuage.lip6.fr/s/H3bpyRGgnCq2NR4?path=%2Fgeonames_ALL)

# %%
schema = "geonameID int, name String, asciiname String, alternatenames string, latitude decimal(8,5), longitude decimal(8,5), feature_class String, feature_code String, country_code String"
geonames =  spark.read.option("header", "False").option("delimiter", "\t").format("csv").load(local_dir + "/" + "allCountries.txt", schema=schema)
geonames.persist()
geonames.createOrReplaceTempView("geonames")
geonames.show(3)
geonames.printSchema()
# Out:
# +---------+--------------------+--------------------+--------------------+--------+---------+-------------+------------+------------+
# |geonameID|                name|           asciiname|      alternatenames|latitude|longitude|feature_class|feature_code|country_code|
# +---------+--------------------+--------------------+--------------------+--------+---------+-------------+------------+------------+
# |  2986043|  Pic de Font Blanca|  Pic de Font Blanca|Pic de Font Blanc...|42.64991|  1.53335|            T|          PK|          AD|
# |  2994701|            Roc Mélé|            Roc Mele|Roc Mele,Roc Mele...|42.58765|  1.74028|            T|          MT|          AD|
# |  3007683|Pic des Langounelles|Pic des Langounelles|Pic des Langounelles|42.61203|  1.47364|            T|          PK|          AD|
# +---------+--------------------+--------------------+--------------------+--------+---------+-------------+------------+------------+
# only showing top 3 rows
#
# root
#  |-- geonameID: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- asciiname: string (nullable = true)
#  |-- alternatenames: string (nullable = true)
#  |-- latitude: decimal(8,5) (nullable = true)
#  |-- longitude: decimal(8,5) (nullable = true)
#  |-- feature_class: string (nullable = true)
#  |-- feature_code: string (nullable = true)
#  |-- country_code: string (nullable = true)

# %% [markdown]
# #####1a) schéma de Geonames
#
# Définir Geonames2 en précisant le schéma : nom et type des attributs.
# Se limiter au 9 premiers attributs donnant des informations sur l'identifiant d'un POI, ses noms, sa position GPS, le code du pays..., ), d'après le document [readme.txt](https://nuage.lip6.fr/s/kaBX3sF3YEzMZHK) dans le dossier [geonames_ALL](https://nuage.lip6.fr/s/H3bpyRGgnCq2NR4?path=%2Fgeonames_ALL)

# %%
# %%sql
# create or replace temp view Geonames2 as
#   select *
#   from Geonames;
#
# select * from Geonames2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>geonameID</th>
#       <th>name</th>
#       <th>asciiname</th>
#       <th>alternatenames</th>
#       <th>latitude</th>
#       <th>longitude</th>
#       <th>feature_class</th>
#       <th>feature_code</th>
#       <th>country_code</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2986043</td>
#       <td>Pic de Font Blanca</td>
#       <td>Pic de Font Blanca</td>
#       <td>Pic de Font Blanca,Pic du Port</td>
#       <td>42.64991</td>
#       <td>1.53335</td>
#       <td>T</td>
#       <td>PK</td>
#       <td>AD</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2994701</td>
#       <td>Roc Mélé</td>
#       <td>Roc Mele</td>
#       <td>Roc Mele,Roc Meler,Roc Mélé</td>
#       <td>42.58765</td>
#       <td>1.74028</td>
#       <td>T</td>
#       <td>MT</td>
#       <td>AD</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3007683</td>
#       <td>Pic des Langounelles</td>
#       <td>Pic des Langounelles</td>
#       <td>Pic des Langounelles</td>
#       <td>42.61203</td>
#       <td>1.47364</td>
#       <td>T</td>
#       <td>PK</td>
#       <td>AD</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3017832</td>
#       <td>Pic de les Abelletes</td>
#       <td>Pic de les Abelletes</td>
#       <td>Pic de la Font-Negre,Pic de la Font-Nègre,Pic ...</td>
#       <td>42.52535</td>
#       <td>1.73343</td>
#       <td>T</td>
#       <td>PK</td>
#       <td>AD</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3017833</td>
#       <td>Estany de les Abelletes</td>
#       <td>Estany de les Abelletes</td>
#       <td>Estany de les Abelletes,Etang de Font-Negre,Ét...</td>
#       <td>42.52915</td>
#       <td>1.73362</td>
#       <td>H</td>
#       <td>LK</td>
#       <td>AD</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>3038902</td>
#       <td>Tosquers</td>
#       <td>Tosquers</td>
#       <td>None</td>
#       <td>42.56587</td>
#       <td>1.48763</td>
#       <td>T</td>
#       <td>SLP</td>
#       <td>AD</td>
#     </tr>
#     <tr>
#       <th>96</th>
#       <td>3038903</td>
#       <td>Canal del Tosquer</td>
#       <td>Canal del Tosquer</td>
#       <td>None</td>
#       <td>42.57114</td>
#       <td>1.52067</td>
#       <td>H</td>
#       <td>STM</td>
#       <td>AD</td>
#     </tr>
#     <tr>
#       <th>97</th>
#       <td>3038904</td>
#       <td>Bosc del Tosquer</td>
#       <td>Bosc del Tosquer</td>
#       <td>None</td>
#       <td>42.57189</td>
#       <td>1.52369</td>
#       <td>V</td>
#       <td>FRST</td>
#       <td>AD</td>
#     </tr>
#     <tr>
#       <th>98</th>
#       <td>3038905</td>
#       <td>Bosc del Tosquer</td>
#       <td>Bosc del Tosquer</td>
#       <td>None</td>
#       <td>42.53793</td>
#       <td>1.60070</td>
#       <td>V</td>
#       <td>FRST</td>
#       <td>AD</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td>3038906</td>
#       <td>Bosc de la Tosca</td>
#       <td>Bosc de la Tosca</td>
#       <td>None</td>
#       <td>42.43912</td>
#       <td>1.45592</td>
#       <td>V</td>
#       <td>FRST</td>
#       <td>AD</td>
#     </tr>
#   </tbody>
# </table>
# <p>100 rows × 9 columns</p>
# </div>

# %% [markdown]
# ##### 1b) Extrait pour le Canada
#
# Définir la vue Geonames_canada pour les POI situés au Canada.

# %%
# %%sql
# create or replace temp view Geonames_canada as
#   select *
#   from Geonames2
#   where country_code = "CA"
#
# ;
#
# cache table Geonames_canada;
#
# select * from  Geonames_canada;
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>geonameID</th>
#       <th>name</th>
#       <th>asciiname</th>
#       <th>alternatenames</th>
#       <th>latitude</th>
#       <th>longitude</th>
#       <th>feature_class</th>
#       <th>feature_code</th>
#       <th>country_code</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3424953</td>
#       <td>Virgin Rocks</td>
#       <td>Virgin Rocks</td>
#       <td>None</td>
#       <td>46.42886</td>
#       <td>-50.81995</td>
#       <td>U</td>
#       <td>RFU</td>
#       <td>CA</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3425041</td>
#       <td>Eastern Shoals</td>
#       <td>Eastern Shoals</td>
#       <td>None</td>
#       <td>46.44743</td>
#       <td>-50.48577</td>
#       <td>U</td>
#       <td>SHSU</td>
#       <td>CA</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3426061</td>
#       <td>Downing Basin</td>
#       <td>Downing Basin</td>
#       <td>None</td>
#       <td>47.05216</td>
#       <td>-50.79163</td>
#       <td>U</td>
#       <td>TRGU</td>
#       <td>CA</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3831549</td>
#       <td>Kane Basin</td>
#       <td>Kane Basin</td>
#       <td>Bassin Kane,Kane Basin</td>
#       <td>79.38860</td>
#       <td>-70.42541</td>
#       <td>H</td>
#       <td>STRT</td>
#       <td>CA</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3831631</td>
#       <td>Georges Shoal</td>
#       <td>Georges Shoal</td>
#       <td>Georges Bank,St. George's Bank,St. George's Shoal</td>
#       <td>41.65444</td>
#       <td>-67.73242</td>
#       <td>U</td>
#       <td>SHLU</td>
#       <td>CA</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>5881729</td>
#       <td>Aalders Landing</td>
#       <td>Aalders Landing</td>
#       <td>None</td>
#       <td>44.83345</td>
#       <td>-64.91549</td>
#       <td>L</td>
#       <td>AREA</td>
#       <td>CA</td>
#     </tr>
#     <tr>
#       <th>96</th>
#       <td>5881730</td>
#       <td>Aalders Lang Brook</td>
#       <td>Aalders Lang Brook</td>
#       <td>None</td>
#       <td>44.86685</td>
#       <td>-64.29875</td>
#       <td>H</td>
#       <td>STM</td>
#       <td>CA</td>
#     </tr>
#     <tr>
#       <th>97</th>
#       <td>5881731</td>
#       <td>Aalders Lang Meadow</td>
#       <td>Aalders Lang Meadow</td>
#       <td>None</td>
#       <td>44.85015</td>
#       <td>-64.31545</td>
#       <td>T</td>
#       <td>PLN</td>
#       <td>CA</td>
#     </tr>
#     <tr>
#       <th>98</th>
#       <td>5881732</td>
#       <td>Aaltanhash Inlet</td>
#       <td>Aaltanhash Inlet</td>
#       <td>Aaltenash Bight</td>
#       <td>53.12854</td>
#       <td>-128.51789</td>
#       <td>H</td>
#       <td>INLT</td>
#       <td>CA</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td>5881733</td>
#       <td>Aaltanhash River</td>
#       <td>Aaltanhash River</td>
#       <td>None</td>
#       <td>53.14741</td>
#       <td>-128.47695</td>
#       <td>H</td>
#       <td>STM</td>
#       <td>CA</td>
#     </tr>
#   </tbody>
# </table>
# <p>100 rows × 9 columns</p>
# </div>

# %% [markdown]
# ### 2) Association entre les POI et Geonames
# Compléter les POI avec des attributs de geonames (par exemple name et [feature code](http://www.geonames.org/export/codes.html))
#
# Décrire la solution que vous proposez.

# %%
# %%sql
# create or replace temp view Geonames_Poi as
#   select geonameID, name, asciiname, alternatenames, latitude, longitude, feature_class, feature_code, country_code, concat(name,feature_code) as poi
#   from Geonames2
#
# ;
#
# select * from  Geonames_Poi;
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>geonameID</th>
#       <th>name</th>
#       <th>asciiname</th>
#       <th>alternatenames</th>
#       <th>latitude</th>
#       <th>longitude</th>
#       <th>feature_class</th>
#       <th>feature_code</th>
#       <th>country_code</th>
#       <th>poi</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2986043</td>
#       <td>Pic de Font Blanca</td>
#       <td>Pic de Font Blanca</td>
#       <td>Pic de Font Blanca,Pic du Port</td>
#       <td>42.64991</td>
#       <td>1.53335</td>
#       <td>T</td>
#       <td>PK</td>
#       <td>AD</td>
#       <td>Pic de Font BlancaPK</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2994701</td>
#       <td>Roc Mélé</td>
#       <td>Roc Mele</td>
#       <td>Roc Mele,Roc Meler,Roc Mélé</td>
#       <td>42.58765</td>
#       <td>1.74028</td>
#       <td>T</td>
#       <td>MT</td>
#       <td>AD</td>
#       <td>Roc MéléMT</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3007683</td>
#       <td>Pic des Langounelles</td>
#       <td>Pic des Langounelles</td>
#       <td>Pic des Langounelles</td>
#       <td>42.61203</td>
#       <td>1.47364</td>
#       <td>T</td>
#       <td>PK</td>
#       <td>AD</td>
#       <td>Pic des LangounellesPK</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3017832</td>
#       <td>Pic de les Abelletes</td>
#       <td>Pic de les Abelletes</td>
#       <td>Pic de la Font-Negre,Pic de la Font-Nègre,Pic ...</td>
#       <td>42.52535</td>
#       <td>1.73343</td>
#       <td>T</td>
#       <td>PK</td>
#       <td>AD</td>
#       <td>Pic de les AbelletesPK</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3017833</td>
#       <td>Estany de les Abelletes</td>
#       <td>Estany de les Abelletes</td>
#       <td>Estany de les Abelletes,Etang de Font-Negre,Ét...</td>
#       <td>42.52915</td>
#       <td>1.73362</td>
#       <td>H</td>
#       <td>LK</td>
#       <td>AD</td>
#       <td>Estany de les AbelletesLK</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>3038902</td>
#       <td>Tosquers</td>
#       <td>Tosquers</td>
#       <td>None</td>
#       <td>42.56587</td>
#       <td>1.48763</td>
#       <td>T</td>
#       <td>SLP</td>
#       <td>AD</td>
#       <td>TosquersSLP</td>
#     </tr>
#     <tr>
#       <th>96</th>
#       <td>3038903</td>
#       <td>Canal del Tosquer</td>
#       <td>Canal del Tosquer</td>
#       <td>None</td>
#       <td>42.57114</td>
#       <td>1.52067</td>
#       <td>H</td>
#       <td>STM</td>
#       <td>AD</td>
#       <td>Canal del TosquerSTM</td>
#     </tr>
#     <tr>
#       <th>97</th>
#       <td>3038904</td>
#       <td>Bosc del Tosquer</td>
#       <td>Bosc del Tosquer</td>
#       <td>None</td>
#       <td>42.57189</td>
#       <td>1.52369</td>
#       <td>V</td>
#       <td>FRST</td>
#       <td>AD</td>
#       <td>Bosc del TosquerFRST</td>
#     </tr>
#     <tr>
#       <th>98</th>
#       <td>3038905</td>
#       <td>Bosc del Tosquer</td>
#       <td>Bosc del Tosquer</td>
#       <td>None</td>
#       <td>42.53793</td>
#       <td>1.60070</td>
#       <td>V</td>
#       <td>FRST</td>
#       <td>AD</td>
#       <td>Bosc del TosquerFRST</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td>3038906</td>
#       <td>Bosc de la Tosca</td>
#       <td>Bosc de la Tosca</td>
#       <td>None</td>
#       <td>42.43912</td>
#       <td>1.45592</td>
#       <td>V</td>
#       <td>FRST</td>
#       <td>AD</td>
#       <td>Bosc de la ToscaFRST</td>
#     </tr>
#   </tbody>
# </table>
# <p>100 rows × 10 columns</p>
# </div>
